// %%
import "fmt"

func isIsomorphic(s string, t string) bool {

	if len(s) != len(t) {
		
		return false
	}

	if len(s) >= 50000 || len(s) <= 1{
		
		return false
	}

	maps := make(map[string]string)

	for i := 0; i < len(s); i++ {
		
		if _, ok := maps[string(s[i])]; !ok {
			
			for _, value := range maps {
				if value == string(t[i]) {
					return false
				}
			}
			maps[string(s[i])] = string(t[i])
			

		} else {

		}

			if _, exist := maps[string(s[i])]; exist {
				if maps[string(s[i])] != string(t[i]){
					return false
				}
			}

		}
		return true
}

	
    

func main (){
	// s := "egg"
	// t := "add"
	// s := "paper" 
	// t := "title"
	// s := "a"
	// t := "a"

	s := "badc"
	t := "baba"

   	result := isIsomorphic(s, t)
	fmt.Println(result)
}
// Out:
// false

// %%
func isHappy(n int) bool {

	if n <= 1 || n >= 2147483647 {
		return false
	}

	sumofsqr := 0
	// sumofvalue := 0

	for n > 0 {
		
		value := n % 10
		fmt.Println ("value: ", value)
		sumofsqr= value * value

		
		
		
		n /= 10
	}

	if sumofsqr == 1 {
			return true
		}

	return false

}

func main () {

	// n := 19
	n := 2
	// n := 1
	// n := 2147483647
	// n := 7
	// n := 1111111

	result := isHappy(n)
	fmt.Println(result)

}
// Out:
// value:  2
// false

// %%
import "fmt"

func main () {
	fmt.Println(7%10)
}
